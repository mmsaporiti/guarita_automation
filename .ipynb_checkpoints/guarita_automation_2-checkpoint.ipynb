# %%
pip install webdriver-manager
# Out:
#   Input In [3]
#     pip install webdriver-manager
#         ^
# SyntaxError: invalid syntax

# %%
from selenium.webdriver.common.by import By

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.3.0-py3-none-any.whl (981 kB)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\sabedot\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.21.0-py3-none-any.whl (358 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sortedcontainers in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: sniffio in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: pycparser in c:\users\sabedot\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\sabedot\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 h11-0.13.0 outcome-1.2.0 selenium-4.3.0 trio-0.21.0 trio-websocket-0.9.2 wsproto-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import os
from time import sleep


# Atualização do webdriver automático - > https://www.youtube.com/watch?v=2EIfXi2-vCI

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# %%
servico = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service = servico)
driver.get('https://www.mercante.transportes.gov.br/g36127/servlet/serpro.siscomex.mercante.servlet.MercanteController')

# %%
# Excel antigo pode ser xls

df = pd.read_excel(r'C:\Users\sabedot\Desktop\automacao\GUARITA 0589S.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7f9cf34e353> in <module>
# ----> 1 df = pd.read_excel(r'C:\Users\sabedot\Desktop\automacao\GUARITA 0589S.xlsx')
#
# NameError: name 'pd' is not defined

# %%
df.shape

# %%
df
# Out:
#    Código da Viagem    Container      Tara   ISO        Lacre  \
# 0     GUARITA 0589S  TTNU4884000  3.745,00  42G1  HLD11879351
# 1     GUARITA 0589S  FSCU4718931  3.720,00  42G1  HLD11879305
# 2     GUARITA 0589S  TRLU4824248  3.680,00  42G1  HLD11879154
# 3     GUARITA 0589S  TCNU3418406  3.700,00  45G1  HLD11879314
# 4     GUARITA 0589S  HLBU2856351  3.900,00  45G1  HLD11879355
# ..              ...          ...       ...   ...          ...
# 68    GUARITA 0589S  MNBU9146345  4.520,00  45R1    BR1586724
# 69    GUARITA 0589S  MNBU9147721  4.520,00  45R1    BR1586723
# 70    GUARITA 0589S  MSWU0012097  4.500,00  45R1    BR1586721
# 71    GUARITA 0589S  MRKU5532606  3.810,00  45G1  MLBR2538055
# 72    GUARITA 0589S  FCIU9246762  3.830,00  45G1      1244448
#
#    Situação do Container Data Vínculo  Solicitação Transporte  Booking/DI  \
# 0                  CHEIO   18/07/2022                   12585    60500289
# 1                  CHEIO   18/07/2022                   12585    60500289
# 2                  CHEIO   18/07/2022                   12585    60500289
# 3                  CHEIO   18/07/2022                   12586    63163180
# 4                  CHEIO   18/07/2022                   12586    63163180
# ..                   ...          ...                     ...         ...
# 68                 CHEIO   25/07/2022                   12720   609168021
# 69                 CHEIO   25/07/2022                   12720   609168021
# 70                 CHEIO   25/07/2022                   12725   609168021
# 71                 CHEIO   26/07/2022                   12727  2aibak02tx
# 72                 CHEIO   26/07/2022                   12740   LA0257803
#
#     Armador Tipo de Operação  \
# 0     HAPAG       Exportação
# 1     HAPAG       Exportação
# 2     HAPAG       Exportação
# 3     HAPAG       Exportação
# 4     HAPAG       Exportação
# ..      ...              ...
# 68   MAERSK       Exportação
# 69   MAERSK       Exportação
# 70   MAERSK       Exportação
# 71  ALIANÇA       Exportação
# 72   LOG-IN    Cabotagem Out
#
#                                               Cliente  Seq. Item     Produto  \
# 0      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2  CNTR 40 DC
# 1      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2  CNTR 40 DC
# 2      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2  CNTR 40 DC
# 3      42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2  CNTR 40 HC
# 4      42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2  CNTR 40 HC
# ..                                                ...        ...         ...
# 68                        01.838.723/0349-60 - BRF SA          1  CNTR 40 RH
# 69                        01.838.723/0349-60 - BRF SA          1  CNTR 40 RH
# 70                        01.838.723/0349-60 - BRF SA          1  CNTR 40 RH
# 71  14.049.467/0027-70 - LACTALIS DO BRASIL - COME...          1  CNTR 40 HC
# 72                            03.471.254/0001-86 - LF          1  CNTR 40 HC
#
#                                           Nota Fiscal  \
# 0                                   791218-1/791258-1
# 1                                   791219-1/791264-1
# 2                                   791216-1/791215-1
# 3                                           1330743-1
# 4                                           1330744-1
# ..                                                ...
# 68                                           157140-1
# 69                                           157106-1
# 70                                           157199-1
# 71                                          2144100-1
# 72  231869-1/50092-5/231870-1/13724-1/1498-2/24500...
#
#                                                   NCM  \
# 0                                            39013090
# 1                                            39013090
# 2                                            39013090
# 3                                            39023000
# 4                                            39023000
# ..                                                ...
# 68                                           02071200
# 69                                           02071200
# 70                         02071200,02071400,05040090
# 71                                           19019090
# 72  94034000/94017100,94018000/94034000/94032000/9...
#
#                                            Peso Bruto     CT-e
# 0                                 12795.750/12795.750  18004-2
# 1                                 12721.500/12795.750  18005-2
# 2                                 12721.500/12795.750  18006-2
# 3                                               24849  18007-2
# 4                                               24849  18008-2
# ..                                                ...      ...
# 68                                          24433.794  18068-2
# 69                                          24393.642  18066-2
# 70                                            22862.7  18067-2
# 71                                              24768  18071-2
# 72  0.720/34.730/0.720/190.000/52.000/30.000/2.000...  18080-2
#
# [73 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Código da Viagem', 'Container', 'Tara', 'ISO', 'Lacre',
#        'Situação do Container', 'Data Vínculo', 'Solicitação Transporte',
#        'Booking/DI', 'Armador', 'Tipo de Operação', 'Cliente', 'Seq. Item',
#        'Produto', 'Nota Fiscal', 'NCM', 'Peso Bruto', 'CT-e'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Código da Viagem          object
# Container                 object
# Tara                      object
# ISO                       object
# Lacre                     object
# Situação do Container     object
# Data Vínculo              object
# Solicitação Transporte     int64
# Booking/DI                object
# Armador                   object
# Tipo de Operação          object
# Cliente                   object
# Seq. Item                  int64
# Produto                   object
# Nota Fiscal               object
# NCM                       object
# Peso Bruto                object
# CT-e                      object
# dtype: object

# %%
lst_ISO = df['ISO'].to_list()
lst_cubagem = []
i = 0
for item in lst_ISO:
    print(str(item) + " " + str(i))
    if item[:2] == '45' or item[:2] == '42':
        lst_cubagem.append('60000')
    elif item[:2] == '22':
        lst_cubagem.append('30000')
    i = i +1
    
print(len(lst_cubagem))
df['Cubagem'] = lst_cubagem
df
# Out:
# 42G1 0
# 42G1 1
# 42G1 2
# 45G1 3
# 45G1 4
# 45G1 5
# 45G1 6
# 45G1 7
# 45G1 8
# 45G1 9
# 45G1 10
# 45G1 11
# 45G1 12
# 45G1 13
# 45G1 14
# 45G1 15
# 45G1 16
# 45G1 17
# 45G1 18
# 45G1 19
# 45G1 20
# 45G1 21
# 45G1 22
# 45G1 23
# 45G1 24
# 45G1 25
# 45G1 26
# 45G1 27
# 45G1 28
# 45G1 29
# 45G1 30
# 45G1 31
# 45G1 32
# 45G1 33
# 45G1 34
# 45G1 35
# 45G1 36
# 45G1 37
# 45G1 38
# 45G1 39
# 45G1 40
# 42G1 41
# 42G1 42
# 42G1 43
# 42G1 44
# 42G1 45
# 45G1 46
# 45G1 47
# 45G1 48
# 22G1 49
# 45G1 50
# 45G1 51
# 45R1 52
# 45R1 53
# 45R1 54
# 45G1 55
# 45G1 56
# 45G1 57
# 45G1 58
# 45R1 59
# 45R1 60
# 45G1 61
# 45G1 62
# 45G1 63
# 45G1 64
# 45G1 65
# 45R1 66
# 45R1 67
# 45R1 68
# 45R1 69
# 45R1 70
# 45G1 71
# 45G1 72
# 73
#    Código da Viagem    Container      Tara   ISO        Lacre  \
# 0     GUARITA 0589S  TTNU4884000  3.745,00  42G1  HLD11879351
# 1     GUARITA 0589S  FSCU4718931  3.720,00  42G1  HLD11879305
# 2     GUARITA 0589S  TRLU4824248  3.680,00  42G1  HLD11879154
# 3     GUARITA 0589S  TCNU3418406  3.700,00  45G1  HLD11879314
# 4     GUARITA 0589S  HLBU2856351  3.900,00  45G1  HLD11879355
# ..              ...          ...       ...   ...          ...
# 68    GUARITA 0589S  MNBU9146345  4.520,00  45R1    BR1586724
# 69    GUARITA 0589S  MNBU9147721  4.520,00  45R1    BR1586723
# 70    GUARITA 0589S  MSWU0012097  4.500,00  45R1    BR1586721
# 71    GUARITA 0589S  MRKU5532606  3.810,00  45G1  MLBR2538055
# 72    GUARITA 0589S  FCIU9246762  3.830,00  45G1      1244448
#
#    Situação do Container Data Vínculo  Solicitação Transporte  Booking/DI  \
# 0                  CHEIO   18/07/2022                   12585    60500289
# 1                  CHEIO   18/07/2022                   12585    60500289
# 2                  CHEIO   18/07/2022                   12585    60500289
# 3                  CHEIO   18/07/2022                   12586    63163180
# 4                  CHEIO   18/07/2022                   12586    63163180
# ..                   ...          ...                     ...         ...
# 68                 CHEIO   25/07/2022                   12720   609168021
# 69                 CHEIO   25/07/2022                   12720   609168021
# 70                 CHEIO   25/07/2022                   12725   609168021
# 71                 CHEIO   26/07/2022                   12727  2aibak02tx
# 72                 CHEIO   26/07/2022                   12740   LA0257803
#
#     Armador Tipo de Operação  \
# 0     HAPAG       Exportação
# 1     HAPAG       Exportação
# 2     HAPAG       Exportação
# 3     HAPAG       Exportação
# 4     HAPAG       Exportação
# ..      ...              ...
# 68   MAERSK       Exportação
# 69   MAERSK       Exportação
# 70   MAERSK       Exportação
# 71  ALIANÇA       Exportação
# 72   LOG-IN    Cabotagem Out
#
#                                               Cliente  Seq. Item     Produto  \
# 0      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2  CNTR 40 DC
# 1      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2  CNTR 40 DC
# 2      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2  CNTR 40 DC
# 3      42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2  CNTR 40 HC
# 4      42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2  CNTR 40 HC
# ..                                                ...        ...         ...
# 68                        01.838.723/0349-60 - BRF SA          1  CNTR 40 RH
# 69                        01.838.723/0349-60 - BRF SA          1  CNTR 40 RH
# 70                        01.838.723/0349-60 - BRF SA          1  CNTR 40 RH
# 71  14.049.467/0027-70 - LACTALIS DO BRASIL - COME...          1  CNTR 40 HC
# 72                            03.471.254/0001-86 - LF          1  CNTR 40 HC
#
#                                           Nota Fiscal  \
# 0                                   791218-1/791258-1
# 1                                   791219-1/791264-1
# 2                                   791216-1/791215-1
# 3                                           1330743-1
# 4                                           1330744-1
# ..                                                ...
# 68                                           157140-1
# 69                                           157106-1
# 70                                           157199-1
# 71                                          2144100-1
# 72  231869-1/50092-5/231870-1/13724-1/1498-2/24500...
#
#                                                   NCM  \
# 0                                            39013090
# 1                                            39013090
# 2                                            39013090
# 3                                            39023000
# 4                                            39023000
# ..                                                ...
# 68                                           02071200
# 69                                           02071200
# 70                         02071200,02071400,05040090
# 71                                           19019090
# 72  94034000/94017100,94018000/94034000/94032000/9...
#
#                                            Peso Bruto     CT-e Cubagem
# 0                                 12795.750/12795.750  18004-2   60000
# 1                                 12721.500/12795.750  18005-2   60000
# 2                                 12721.500/12795.750  18006-2   60000
# 3                                               24849  18007-2   60000
# 4                                               24849  18008-2   60000
# ..                                                ...      ...     ...
# 68                                          24433.794  18068-2   60000
# 69                                          24393.642  18066-2   60000
# 70                                            22862.7  18067-2   60000
# 71                                              24768  18071-2   60000
# 72  0.720/34.730/0.720/190.000/52.000/30.000/2.000...  18080-2   60000
#
# [73 rows x 19 columns]

# %%
df_guarita = df[['ISO', 'Container', 'Tara', 'Peso Bruto', 'NCM', 'Lacre', 'Cubagem' ]]

# %%
df_guarita.head()
# Out:
#     ISO    Container      Tara           Peso Bruto       NCM        Lacre  \
# 0  42G1  TTNU4884000  3.745,00  12795.750/12795.750  39013090  HLD11879351
# 1  42G1  FSCU4718931  3.720,00  12721.500/12795.750  39013090  HLD11879305
# 2  42G1  TRLU4824248  3.680,00  12721.500/12795.750  39013090  HLD11879154
# 3  45G1  TCNU3418406  3.700,00                24849  39023000  HLD11879314
# 4  45G1  HLBU2856351  3.900,00                24849  39023000  HLD11879355
#
#   Cubagem
# 0   60000
# 1   60000
# 2   60000
# 3   60000
# 4   60000

# %%
df_guarita.dtypes
# Out:
# ISO           object
# Container     object
# Tara          object
# Peso Bruto    object
# NCM           object
# Lacre         object
# Cubagem       object
# dtype: object

# %%
guarita_dict = df_guarita.to_dict(orient = 'index')
guarita_dict
# Out:
# {0: {'ISO': '42G1',
#   'Container': 'TTNU4884000',
#   'Tara': '3.745,00',
#   'Peso Bruto': '12795.750/12795.750',
#   'NCM': 39013090,
#   'Lacre': 'HLD11879351',
#   'Cubagem': '60000'},
#  1: {'ISO': '42G1',
#   'Container': 'FSCU4718931',
#   'Tara': '3.720,00',
#   'Peso Bruto': '12721.500/12795.750',
#   'NCM': 39013090,
#   'Lacre': 'HLD11879305',
#   'Cubagem': '60000'},
#  2: {'ISO': '42G1',
#   'Container': 'TRLU4824248',
#   'Tara': '3.680,00',
#   'Peso Bruto': '12721.500/12795.750',
#   'NCM': 39013090,
#   'Lacre': 'HLD11879154',
#   'Cubagem': '60000'},
#  3: {'ISO': '45G1',
#   'Container': 'TCNU3418406',
#   'Tara': '3.700,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879314',
#   'Cubagem': '60000'},
#  4: {'ISO': '45G1',
#   'Container': 'HLBU2856351',
#   'Tara': '3.900,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879355',
#   'Cubagem': '60000'},
#  5: {'ISO': '45G1',
#   'Container': 'FANU1199866',
#   'Tara': '3.680,00',
#   'Peso Bruto': 24773.7,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879360',
#   'Cubagem': '60000'},
#  6: {'ISO': '45G1',
#   'Container': 'TGBU6127050',
#   'Tara': '3.700,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879358',
#   'Cubagem': '60000'},
#  7: {'ISO': '45G1',
#   'Container': 'HAMU1279893',
#   'Tara': '3.900,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879254',
#   'Cubagem': '60000'},
#  8: {'ISO': '45G1',
#   'Container': 'TGHU9448267',
#   'Tara': '3.890,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879151',
#   'Cubagem': '60000'},
#  9: {'ISO': '45G1',
#   'Container': 'HLBU2018180',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25100,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879301',
#   'Cubagem': '60000'},
#  10: {'ISO': '45G1',
#   'Container': 'SEGU5116306',
#   'Tara': '3.850,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLG3875630',
#   'Cubagem': '60000'},
#  11: {'ISO': '45G1',
#   'Container': 'TCLU6478377',
#   'Tara': '3.840,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879309',
#   'Cubagem': '60000'},
#  12: {'ISO': '45G1',
#   'Container': 'HLBU2859303',
#   'Tara': '3.900,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879155',
#   'Cubagem': '60000'},
#  13: {'ISO': '45G1',
#   'Container': 'BEAU5092820',
#   'Tara': '3.700,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879255',
#   'Cubagem': '60000'},
#  14: {'ISO': '45G1',
#   'Container': 'UACU5079880',
#   'Tara': '3.960,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLG3875626',
#   'Cubagem': '60000'},
#  15: {'ISO': '45G1',
#   'Container': 'UACU6003004',
#   'Tara': '3.800,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLG3875678',
#   'Cubagem': '60000'},
#  16: {'ISO': '45G1',
#   'Container': 'FANU1455551',
#   'Tara': '3.680,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11879303',
#   'Cubagem': '60000'},
#  17: {'ISO': '45G1',
#   'Container': 'UACU5741533',
#   'Tara': '3.800,00',
#   'Peso Bruto': 24849,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858132',
#   'Cubagem': '60000'},
#  18: {'ISO': '45G1',
#   'Container': 'MSKU0054846',
#   'Tara': '4.000,00',
#   'Peso Bruto': 25542,
#   'NCM': 39012029,
#   'Lacre': 'BR1629523',
#   'Cubagem': '60000'},
#  19: {'ISO': '45G1',
#   'Container': 'HASU4598772',
#   'Tara': '3.860,00',
#   'Peso Bruto': 25542,
#   'NCM': 39012029,
#   'Lacre': 'BR1629513',
#   'Cubagem': '60000'},
#  20: {'ISO': '45G1',
#   'Container': 'TCKU7861866',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629557',
#   'Cubagem': '60000'},
#  21: {'ISO': '45G1',
#   'Container': 'SEKU4591158',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629590',
#   'Cubagem': '60000'},
#  22: {'ISO': '45G1',
#   'Container': 'MRKU4964884',
#   'Tara': '3.810,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629559',
#   'Cubagem': '60000'},
#  23: {'ISO': '45G1',
#   'Container': 'MRKU4431993',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629575',
#   'Cubagem': '60000'},
#  24: {'ISO': '45G1',
#   'Container': 'MRKU2235970',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629579',
#   'Cubagem': '60000'},
#  25: {'ISO': '45G1',
#   'Container': 'TCNU2621804',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629593',
#   'Cubagem': '60000'},
#  26: {'ISO': '45G1',
#   'Container': 'HASU4690343',
#   'Tara': '3.860,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629555',
#   'Cubagem': '60000'},
#  27: {'ISO': '45G1',
#   'Container': 'HASU4894898',
#   'Tara': '3.860,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'BR1629551',
#   'Cubagem': '60000'},
#  28: {'ISO': '45G1',
#   'Container': 'CMAU7497064',
#   'Tara': '3.700,00',
#   'Peso Bruto': '3.700,00',
#   'NCM': 55032090,
#   'Lacre': 'C1757739',
#   'Cubagem': '60000'},
#  29: {'ISO': '45G1',
#   'Container': 'TCLU1503498',
#   'Tara': '3.850,00',
#   'Peso Bruto': '3.850,00',
#   'NCM': 55032090,
#   'Lacre': 'C1757776',
#   'Cubagem': '60000'},
#  30: {'ISO': '45G1',
#   'Container': 'BMOU6435086',
#   'Tara': '3.850,00',
#   'Peso Bruto': '3.850,00',
#   'NCM': 55032090,
#   'Lacre': 'C1764589',
#   'Cubagem': '60000'},
#  31: {'ISO': '45G1',
#   'Container': 'ECMU9936359',
#   'Tara': '3.900,00',
#   'Peso Bruto': '3.900,00',
#   'NCM': 55032090,
#   'Lacre': 'C1687436',
#   'Cubagem': '60000'},
#  32: {'ISO': '45G1',
#   'Container': 'CMAU6231362',
#   'Tara': '3.700,00',
#   'Peso Bruto': '3.700,00',
#   'NCM': 55032090,
#   'Lacre': 'C1764494',
#   'Cubagem': '60000'},
#  33: {'ISO': '45G1',
#   'Container': 'MAGU5334833',
#   'Tara': '3.810,00',
#   'Peso Bruto': '3.810,00',
#   'NCM': 55032090,
#   'Lacre': 'C1764495',
#   'Cubagem': '60000'},
#  34: {'ISO': '45G1',
#   'Container': 'MRSU5162192',
#   'Tara': '3.720,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'BR2327106',
#   'Cubagem': '60000'},
#  35: {'ISO': '45G1',
#   'Container': 'MRSU5837110',
#   'Tara': '3.720,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'BR2327107',
#   'Cubagem': '60000'},
#  36: {'ISO': '45G1',
#   'Container': 'MRSU6051573',
#   'Tara': '3.720,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'BR2327108',
#   'Cubagem': '60000'},
#  37: {'ISO': '45G1',
#   'Container': 'MTSU9619634',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'BR2327109',
#   'Cubagem': '60000'},
#  38: {'ISO': '45G1',
#   'Container': 'TCNU9884572',
#   'Tara': '3.840,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'BR2330824',
#   'Cubagem': '60000'},
#  39: {'ISO': '45G1',
#   'Container': 'MRKU4404391',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'BR1586717',
#   'Cubagem': '60000'},
#  40: {'ISO': '45G1',
#   'Container': 'SUDU8657120',
#   'Tara': '3.860,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'BR2330973',
#   'Cubagem': '60000'},
#  41: {'ISO': '42G1',
#   'Container': 'HLBU1395044',
#   'Tara': '3.800,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858070',
#   'Cubagem': '60000'},
#  42: {'ISO': '42G1',
#   'Container': 'GVCU4035698',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39011030,
#   'Lacre': 'HLD11857972',
#   'Cubagem': '60000'},
#  43: {'ISO': '42G1',
#   'Container': 'HLXU5211409',
#   'Tara': '3.980,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39011030,
#   'Lacre': 'HLD11857997',
#   'Cubagem': '60000'},
#  44: {'ISO': '42G1',
#   'Container': 'HLXU5348177',
#   'Tara': '3.800,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858025',
#   'Cubagem': '60000'},
#  45: {'ISO': '42G1',
#   'Container': 'UACU8379109',
#   'Tara': '3.600,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858089',
#   'Cubagem': '60000'},
#  46: {'ISO': '45G1',
#   'Container': 'HAMU1318650',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39013090,
#   'Lacre': 'HLD11858099',
#   'Cubagem': '60000'},
#  47: {'ISO': '45G1',
#   'Container': 'UACU5919245',
#   'Tara': '3.800,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39013090,
#   'Lacre': 'HLD11857979',
#   'Cubagem': '60000'},
#  48: {'ISO': '45G1',
#   'Container': 'UACU5852434',
#   'Tara': '3.800,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39013090,
#   'Lacre': 'HLD11858097',
#   'Cubagem': '60000'},
#  49: {'ISO': '22G1',
#   'Container': 'DFSU1364459',
#   'Tara': '2.160,00',
#   'Peso Bruto': 11884,
#   'NCM': 41079210,
#   'Lacre': 'HLD11858093',
#   'Cubagem': '30000'},
#  50: {'ISO': '45G1',
#   'Container': 'TGBU6070593',
#   'Tara': '3.700,00',
#   'Peso Bruto': 21274,
#   'NCM': 39023000,
#   'Lacre': 'HLD11883441',
#   'Cubagem': '60000'},
#  51: {'ISO': '45G1',
#   'Container': 'TCNU1836916',
#   'Tara': '3.700,00',
#   'Peso Bruto': 21274,
#   'NCM': 39023000,
#   'Lacre': 'BR2327105',
#   'Cubagem': '60000'},
#  52: {'ISO': '45R1',
#   'Container': 'MNBU3268177',
#   'Tara': '4.420,00',
#   'Peso Bruto': 24460.8,
#   'NCM': '02071200',
#   'Lacre': 'BR1629959',
#   'Cubagem': '60000'},
#  53: {'ISO': '45R1',
#   'Container': 'MNBU0670114',
#   'Tara': '4.500,00',
#   'Peso Bruto': 24480.918,
#   'NCM': '02071200',
#   'Lacre': 'BR1629955',
#   'Cubagem': '60000'},
#  54: {'ISO': '45R1',
#   'Container': 'MNBU0629785',
#   'Tara': '4.500,00',
#   'Peso Bruto': 24393.642,
#   'NCM': '02071200',
#   'Lacre': 'BR1629956',
#   'Cubagem': '60000'},
#  55: {'ISO': '45G1',
#   'Container': 'CAIU8761754',
#   'Tara': '3.830,00',
#   'Peso Bruto': 25245,
#   'NCM': 39011030,
#   'Lacre': 1243213,
#   'Cubagem': '60000'},
#  56: {'ISO': '45G1',
#   'Container': 'CAIU4840201',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25245,
#   'NCM': 39011030,
#   'Lacre': 1274558,
#   'Cubagem': '60000'},
#  57: {'ISO': '45G1',
#   'Container': 'TCLU8805680',
#   'Tara': '3.840,00',
#   'Peso Bruto': 25245,
#   'NCM': 39011030,
#   'Lacre': 1274555,
#   'Cubagem': '60000'},
#  58: {'ISO': '45G1',
#   'Container': 'AMFU8924149',
#   'Tara': '3.940,00',
#   'Peso Bruto': 25245,
#   'NCM': 39011030,
#   'Lacre': 1243215,
#   'Cubagem': '60000'},
#  59: {'ISO': '45R1',
#   'Container': 'MNBU0541924',
#   'Tara': '4.500,00',
#   'Peso Bruto': 24441.142,
#   'NCM': '02071200',
#   'Lacre': 'BR1629954',
#   'Cubagem': '60000'},
#  60: {'ISO': '45R1',
#   'Container': 'MSWU0071227',
#   'Tara': '4.500,00',
#   'Peso Bruto': 24333.556,
#   'NCM': '02071200',
#   'Lacre': 'BR1629960',
#   'Cubagem': '60000'},
#  61: {'ISO': '45G1',
#   'Container': 'MRSU5179174',
#   'Tara': '3.720,00',
#   'Peso Bruto': 25245,
#   'NCM': 39012029,
#   'Lacre': 'BR1629263',
#   'Cubagem': '60000'},
#  62: {'ISO': '45G1',
#   'Container': 'MRSU6246976',
#   'Tara': '3.720,00',
#   'Peso Bruto': 25245,
#   'NCM': 39012029,
#   'Lacre': 'BR1629264',
#   'Cubagem': '60000'},
#  63: {'ISO': '45G1',
#   'Container': 'MRSU5212101',
#   'Tara': '3.720,00',
#   'Peso Bruto': 25500,
#   'NCM': 39012029,
#   'Lacre': 'BR1629265',
#   'Cubagem': '60000'},
#  64: {'ISO': '45G1',
#   'Container': 'CIPU5234204',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39012029,
#   'Lacre': 'BR1629266',
#   'Cubagem': '60000'},
#  65: {'ISO': '45G1',
#   'Container': 'TLLU6910257',
#   'Tara': '3.700,00',
#   'Peso Bruto': 21644.449,
#   'NCM': 19019090,
#   'Lacre': 'BR2538157',
#   'Cubagem': '60000'},
#  66: {'ISO': '45R1',
#   'Container': 'MNBU4098054',
#   'Tara': '4.350,00',
#   'Peso Bruto': 24460.8,
#   'NCM': '02071200',
#   'Lacre': 'BR1586756',
#   'Cubagem': '60000'},
#  67: {'ISO': '45R1',
#   'Container': 'MNBU0119117',
#   'Tara': '4.600,00',
#   'Peso Bruto': 24433.794,
#   'NCM': '02071200',
#   'Lacre': 'BR1586622',
#   'Cubagem': '60000'},
#  68: {'ISO': '45R1',
#   'Container': 'MNBU9146345',
#   'Tara': '4.520,00',
#   'Peso Bruto': 24433.794,
#   'NCM': '02071200',
#   'Lacre': 'BR1586724',
#   'Cubagem': '60000'},
#  69: {'ISO': '45R1',
#   'Container': 'MNBU9147721',
#   'Tara': '4.520,00',
#   'Peso Bruto': 24393.642,
#   'NCM': '02071200',
#   'Lacre': 'BR1586723',
#   'Cubagem': '60000'},
#  70: {'ISO': '45R1',
#   'Container': 'MSWU0012097',
#   'Tara': '4.500,00',
#   'Peso Bruto': 22862.7,
#   'NCM': '02071200,02071400,05040090',
#   'Lacre': 'BR1586721',
#   'Cubagem': '60000'},
#  71: {'ISO': '45G1',
#   'Container': 'MRKU5532606',
#   'Tara': '3.810,00',
#   'Peso Bruto': 24768,
#   'NCM': 19019090,
#   'Lacre': 'MLBR2538055',
#   'Cubagem': '60000'},
#  72: {'ISO': '45G1',
#   'Container': 'FCIU9246762',
#   'Tara': '3.830,00',
#   'Peso Bruto': '0.720/34.730/0.720/190.000/52.000/30.000/2.000/15.000/6.000/40.000/1224.000/5.180/85.000/20.910/130.200/10.000/180.000/19.845/88.795/305.887/823.000/74.875/3280.520/54.269/801.949/690.020/28.000/90.000/17.000/288.660/334.970/77.730/6.960/105.200/328.300/80.060/31.900/0.030/1126.990/542.960/378.360/1080.950/493.860/0.480/1.000/9.900/12.150/2.960/1.750/10.850/1.400/4.050/1.840/3.810/0.220/33.090/1.428/102.100/5.600/10.681/16.207/154.400/27.050/82.000/406.000',
#   'NCM': '94034000/94017100,94018000/94034000/94032000/94016100/94017900/94039900/94017900/94039900/94039900/22041010,22041090/94016100/94017100/39241000,49029000,49111090,61091000/39231090/94019900/94017100/94039100/44101129,94039100/85366990,94013900,94017900,94033000,94039100,94039900/73182200,83021000,83022000/94034000,94039900/73181400,73181600,73182300,83014000,83021000,83022000,83024100,83082000/94034000,94039900/94034000,94035000,94039900/94034000,94035000,94039900/94016100/94016100/94036000/94034000/94034000,94035000/94034000,94035000/94034000,94035000/94034000,94035000/94034000/94034000,94035000/94034000,94035000/94034000/94034000,94035000,94036000/94034000,94035000/94034000,94035000/94034000,94035000,94036000/94034000,94035000/94034000/94034000,94035000/94034000/94034000,94035000/94035000/94034000/94034000/94034000/94034000,94035000/94034000/94034000/94034000/94034000/94039900/94034000,94035000/94039900/94039900/94039900/94016100,94032000/94034000/94016100/94016100',
#   'Lacre': 1244448,
#   'Cubagem': '60000'}}

# %%
len(guarita_dict)
# Out:
# 73

# %%
# Teste
driver.switch_to.default_content()


driver.switch_to.frame('Principal')
e = driver.find_element(By.XPATH, '/html/body/form/div/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[2]/input[1]').send_keys('teste')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[4]/input').send_keys('test')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[2]/input').send_keys('test')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[4]/input').send_keys('test')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[3]/td[2]/input').send_keys('test')
e = driver.find_element(By.XPATH, '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[1]/fieldset/table/tbody/tr[1]/td[2]/input[1]').send_keys('test')
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# Input In [45], in <cell line: 2>()
#       1 # Teste
# ----> 2 driver.switch_to.default_content()
#       5 driver.switch_to.frame('Principal')
#       6 e = driver.find_element(By.XPATH, '/html/body/form/div/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[2]/input[1]').send_keys('teste')
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\switch_to.py:68, in SwitchTo.default_content(self)
#      59 def default_content(self) -> None:
#      60     """
#      61     Switch focus to the default frame.
#      62
#    (...)
#      66             driver.switch_to.default_content()
#      67     """
# ---> 68     self._driver.execute(Command.SWITCH_TO_FRAME, {'id': None})
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:246, in ErrorHandler.check_response(self, response)
#     244     elif 'alert' in value:
#     245         alert_text = value['alert'].get('text')
# --> 246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
#     247 raise exception_class(message, screen, stacktrace)
#
# UnexpectedAlertPresentException: Alert Text: Esta sessÃ£o foi encerrada!!! FaÃ§aa o login novamente.
# Message: unexpected alert open: {Alert text : Esta sessÃ£o foi encerrada!!! FaÃ§aa o login novamente.}
#   (Session info: chrome=104.0.5112.81)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007B78B3+2193587]
# 	Ordinal0 [0x00750681+1771137]
# 	Ordinal0 [0x006641A8+803240]
# 	Ordinal0 [0x006BD952+1169746]
# 	Ordinal0 [0x006AD5C6+1103302]
# 	Ordinal0 [0x006877E0+948192]
# 	Ordinal0 [0x006886E6+952038]
# 	GetHandleVerifier [0x00A60CB2+2738370]
# 	GetHandleVerifier [0x00A521B8+2678216]
# 	GetHandleVerifier [0x008417AA+512954]
# 	GetHandleVerifier [0x00840856+509030]
# 	Ordinal0 [0x0075743B+1799227]
# 	Ordinal0 [0x0075BB68+1817448]
# 	Ordinal0 [0x0075BC55+1817685]
# 	Ordinal0 [0x00765230+1856048]
# 	BaseThreadInitThunk [0x7704FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77887A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77887A6E+238]

# %%
#sleep(3)
count = 0
driver.maximize_window
frames = driver.find_elements()
driver.switch_to.default_content()
driver.switch_to.frame('Principal')

while count <= len(guarita_dict):


    for item in guarita_dict[count]:
#ISO     
    
        # get xpath for ISO
        #print(driver.name)
        #print(driver.current_url)
        e = driver.find_element('name',"ItemCarga_tipoContainer")
        e = driver.find_element(By.XPATH, '/html/body/form/div/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[2]/input[1]')
        e.send_keys(guarita_dict[count]['ISO'])
        
        # print confirmação
        print(guarita_dict[count]['ISO'])
        sleep(0.5)

#CONTAINER
        # get xpath for Container 
        
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[4]/input')
        e.send_keys(guarita_dict[count]['Container'])

        # print confirmação
        print(guarita_dict[count]['Container'])
        sleep(0.5)

#TARA
        # get xpath for Tara
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[2]/input')
        e.send_keys(guarita_dict[count]['Tara'])
        
        # print confirmação
        print(guarita_dict[count]['Tara'])
        sleep(0.5)

#PESO_BRUTO
        # get xpath for Peso Bruto
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[4]/input')
        e.send_keys(guarita_dict[count]['Peso Bruto'])
        
        # print confirmação
        print(guarita_dict[count]['Peso Bruto'])
        sleep(0.5)
        
        
#CUBAGEM
        # startswith
       
        # get xpath for CUBAGEM
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[3]/td[2]/input')
        e.send_keys(guarita_dict[count]['Cubagem'])
        
        # print confirmação
        print(guarita_dict[count]['Cubagem'])
        sleep(0.5)
        
# NCM
        ncms = str(guarita_dict[count]['NCM']).split('/')            
        
        # split "/" e loop for para múltiplas inserções
        for item in ncms:
            # get xpath for NCM
            e = driver.find_element(By.XPATH, '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[1]/fieldset/table/tbody/tr[1]/td[2]/input[1]')
            e.send_keys(item)
            # get xpath for "incluir"
            e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[1]/fieldset/table/tbody/tr[2]/td/input')
            e.click()
            print(item)
            sleep(0.5)
        
        
        ##### SE TIVER / INSERIR VÁRIAS VEZES. EX: PRIMEIRA VEZ, ATÉ A BARRA; SEGUNDA VEZ, ATÉ A PRÓXIMA BARRA;
        ### TERCEIRA VEZ, ATÉ A PRÓXIMA BARRA
        
        

        #get xpath for Lacre
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td[2]/input')
        e.send_keys(guarita_dict[count]['Lacre'])
        
        print(guarita_dict[count]['Lacre'])
        sleep(0.5)
        
        # get xpath for "incluir"
        driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/input').click()
        
        print('Click - Clicar em inserir Item.')
        sleep(0.5)
        
        #input('press enter to continue')
        
        
# INCLUIR ITEM        
        driver.find_element('xpath', '//*[@id="divCampos"]/p[2]/input[1]').click()
    
# INCLUIR NOVO ITEM - radio button

        driver.find_element('xpath', '/html/body/form[1]/fieldset[5]/table/tbody/tr/td[1]/input[1]').click()
        print('marcar inserir novo item')
        sleep(0.5)
        
# ENVIAR
        # driver.find_element('xpath', '/html/body/form[1]/p[2]/input')
        print('clicar em enviar')
        sleep(0.5)

        count += 1
        input('Aperte enter para prosseguir')

        print('----- next one-----')
# Out:
# 42G1
# TTNU4884000
# 3.745,00
# 12795.750/12795.750
# 60000
# 39013090
# HLD11879351
# Click - Clicar em inserir Item.
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [52], in <cell line: 8>()
#     102         driver.find_element('xpath', '//*[@id="divCampos"]/p[2]/input[1]').click()
#     104 # INCLUIR NOVO ITEM - radio button
# --> 106         driver.find_element('xpath', '/html/body/form[1]/fieldset[5]/table/tbody/tr/td[1]/input[1]').click()
#     107         print('marcar inserir novo item')
#     108         sleep(0.5)
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:857, in WebDriver.find_element(self, by, value)
#     854     by = By.CSS_SELECTOR
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/form[1]/fieldset[5]/table/tbody/tr/td[1]/input[1]"}
#   (Session info: chrome=104.0.5112.81)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007B78B3+2193587]
# 	Ordinal0 [0x00750681+1771137]
# 	Ordinal0 [0x006641A8+803240]
# 	Ordinal0 [0x006924A0+992416]
# 	Ordinal0 [0x0069273B+993083]
# 	Ordinal0 [0x006BF7C2+1177538]
# 	Ordinal0 [0x006AD7F4+1103860]
# 	Ordinal0 [0x006BDAE2+1170146]
# 	Ordinal0 [0x006AD5C6+1103302]
# 	Ordinal0 [0x006877E0+948192]
# 	Ordinal0 [0x006886E6+952038]
# 	GetHandleVerifier [0x00A60CB2+2738370]
# 	GetHandleVerifier [0x00A521B8+2678216]
# 	GetHandleVerifier [0x008417AA+512954]
# 	GetHandleVerifier [0x00840856+509030]
# 	Ordinal0 [0x0075743B+1799227]
# 	Ordinal0 [0x0075BB68+1817448]
# 	Ordinal0 [0x0075BC55+1817685]
# 	Ordinal0 [0x00765230+1856048]
# 	BaseThreadInitThunk [0x7704FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77887A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77887A6E+238]

# %%
nnn = "34933223/3243232/1231312"

# %%
nnn = nnn.split('/')

# %%
for item in nnn:
    print(item)
# Out:
# 34933223
# 3243232
# 1231312

# %%
dict_df = df.to_dict(orient = 'index')

# %%
dict_df
