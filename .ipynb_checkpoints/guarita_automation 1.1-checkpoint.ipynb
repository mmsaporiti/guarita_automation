# %%
pip install webdriver-manager
# Out:
#   Input In [3]
#     pip install webdriver-manager
#         ^
# SyntaxError: invalid syntax

# %%
from selenium.webdriver.common.by import By

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.3.0-py3-none-any.whl (981 kB)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\sabedot\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.21.0-py3-none-any.whl (358 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sortedcontainers in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: sniffio in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\sabedot\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: pycparser in c:\users\sabedot\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\sabedot\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\sabedot\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 h11-0.13.0 outcome-1.2.0 selenium-4.3.0 trio-0.21.0 trio-websocket-0.9.2 wsproto-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import os
from time import sleep


# Atualização do webdriver automático - > https://www.youtube.com/watch?v=2EIfXi2-vCI

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# %%
servico = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service = servico)
driver.get('https://www.mercante.transportes.gov.br/g36127/servlet/serpro.siscomex.mercante.servlet.MercanteController')

# %%
# problema com arquivo antigo. excel até 2003 ->> xlsx ou xls
df = pd.read_excel(r'C:\Users\sabedot\Desktop\automacao\GUARITA 0589S.xls')

# %%
df.shape
# Out:
# (44, 18)

# %%
df
# Out:
#    Código da Viagem    Container      Tara   ISO        Lacre  \
# 0     GUARITA 0597S  CAAU6627492  3.700,00  45G1  MLBR2540106
# 1     GUARITA 0597S  GESU6076986  3.870,00  45G1  MLBR2540108
# 2     GUARITA 0597S  MRKU3535226  3.880,00  45G1  MLBR2540112
# 3     GUARITA 0597S  MRKU4708028  3.880,00  45G1  MLBR2540113
# 4     GUARITA 0597S  MRKU5427806  3.810,00  45G1  MLBR2540114
# 5     GUARITA 0597S  MSKU1383240  3.880,00  45G1  MLBR2540115
# 6     GUARITA 0597S  MSKU1840520  3.880,00  45G1  MLBR2540116
# 7     GUARITA 0597S  MSKU1993725  3.880,00  45G1  MLBR2540117
# 8     GUARITA 0597S  MSKU9617025  3.910,00  45G1  MLBR2540118
# 9     GUARITA 0597S  TCLU8382865  4.000,00  45G1  MLBR2540119
# 10    GUARITA 0597S  TRHU8485843  3.700,00  45G1  MLBR2540120
# 11    GUARITA 0597S  HLXU6500920  4.090,00  45G1  HLD11880126
# 12    GUARITA 0597S  FANU1469555  3.680,00  45G1  HLD11880127
# 13    GUARITA 0597S  TCNU1800831  3.700,00  45G1  HLD11880125
# 14    GUARITA 0597S  MAGU5493650  4.000,00  45G1  MLBR2540162
# 15    GUARITA 0597S  TCNU8123440  3.700,00  45G1  MLBR2540163
# 16    GUARITA 0597S  UACU5892099  3.900,00  45G1  HLD11858371
# 17    GUARITA 0597S  UACU5642377  3.800,00  45G1  HLD11858323
# 18    GUARITA 0597S  HLBU1078179  3.900,00  45G1  HLD11858328
# 19    GUARITA 0597S  HLBU2176945  3.900,00  45G1  HLD11858382
# 20    GUARITA 0597S  FFAU1336836  3.700,00  45G1  HLD11858326
# 21    GUARITA 0597S  TGHU9453073  3.890,00  45G1  HLD11858353
# 22    GUARITA 0597S  HLBU3234692  3.900,00  45G1  HLD11858388
# 23    GUARITA 0597S  HLXU8349161  3.900,00  45G1  HLD11858345
# 24    GUARITA 0597S  HLBU2813513  3.910,00  45G1  HLD11858268
# 25    GUARITA 0597S  FANU1401730  3.900,00  45G1  HLD11858288
# 26    GUARITA 0597S  HLBU2116695  3.900,00  45G1  HLD11858278
# 27    GUARITA 0597S  UETU5734117  3.700,00  45G1  HLD11858372
# 28    GUARITA 0597S  TCLU8365868  3.840,00  45G1  HLD11858346
# 29    GUARITA 0597S  HAMU1302150  3.900,00  45G1  HLD11858295
# 30    GUARITA 0597S  UACU5251454  3.970,00  45G1  HLD11858387
# 31    GUARITA 0597S  HLBU2458743  3.900,00  45G1  HLD11858304
# 32    GUARITA 0597S  HLBU2657405  3.900,00  45G1  HLD11858383
# 33    GUARITA 0597S  CAIU4259809  3.750,00  45G1  HLD11858385
# 34    GUARITA 0597S  HLXU8527160  3.900,00  45G1  HLD11858322
# 35    GUARITA 0597S  UACU5878336  3.800,00  45G1   HLG3885740
# 36    GUARITA 0597S  HLBU1855670  3.900,00  45G1  HLD11858270
# 37    GUARITA 0597S  SEGU5679830  3.830,00  45G1  HLD11858330
# 38    GUARITA 0597S  CAIU8521922  3.820,00  45G1  HLD11861261
# 39    GUARITA 0597S  HAMU1306411  3.900,00  45G1  HLD11858350
# 40    GUARITA 0597S  HLXU8415448  3.900,00  45G1  HLD11861248
# 41    GUARITA 0597S  UACU5304699  3.970,00  45G1  HLD11861250
# 42    GUARITA 0597S  TCLU8643336  3.840,00  45G1  HLD11880128
# 43    GUARITA 0597S  CIPU5246519  3.700,00  45G1    BR1585138
#
#    Situação do Container Data Vínculo  Solicitação Transporte  Booking/DI  \
# 0                  VAZIO   26/07/2022                   12737   219016888
# 1                  VAZIO   26/07/2022                   12737   219016888
# 2                  VAZIO   26/07/2022                   12737   219016888
# 3                  VAZIO   26/07/2022                   12737   219016888
# 4                  VAZIO   26/07/2022                   12737   219016888
# 5                  VAZIO   26/07/2022                   12737   219016888
# 6                  VAZIO   26/07/2022                   12737   219016888
# 7                  VAZIO   26/07/2022                   12737   219016888
# 8                  VAZIO   26/07/2022                   12737   219016888
# 9                  VAZIO   26/07/2022                   12737   219016888
# 10                 VAZIO   26/07/2022                   12737   219016888
# 11                 VAZIO   01/08/2022                   12775    64167899
# 12                 VAZIO   01/08/2022                   12776    65167898
# 13                 VAZIO   01/08/2022                   12777    61502559
# 14                 VAZIO   01/08/2022                   12790   219763096
# 15                 VAZIO   01/08/2022                   12790   219763096
# 16                 VAZIO   02/08/2022                   12809    67168141
# 17                 VAZIO   02/08/2022                   12818    68167618
# 18                 VAZIO   02/08/2022                   12818    68167618
# 19                 VAZIO   02/08/2022                   12818    68167618
# 20                 VAZIO   02/08/2022                   12818    68167618
# 21                 VAZIO   02/08/2022                   12818    68167618
# 22                 VAZIO   02/08/2022                   12818    68167618
# 23                 VAZIO   02/08/2022                   12818    68167618
# 24                 VAZIO   02/08/2022                   12818    68167618
# 25                 VAZIO   02/08/2022                   12818    68167618
# 26                 VAZIO   02/08/2022                   12818    68167618
# 27                 VAZIO   02/08/2022                   12818    68167618
# 28                 VAZIO   02/08/2022                   12818    68167618
# 29                 VAZIO   02/08/2022                   12818    68167618
# 30                 VAZIO   02/08/2022                   12818    68167618
# 31                 VAZIO   02/08/2022                   12823    63835235
# 32                 VAZIO   02/08/2022                   12823    63835235
# 33                 VAZIO   02/08/2022                   12823    63835235
# 34                 VAZIO   02/08/2022                   12823    63835235
# 35                 VAZIO   03/08/2022                   12841    65167970
# 36                 VAZIO   03/08/2022                   12850    60506754
# 37                 VAZIO   03/08/2022                   12850    60506754
# 38                 VAZIO   03/08/2022                   12850    60506754
# 39                 VAZIO   03/08/2022                   12850    60506754
# 40                 VAZIO   03/08/2022                   12850    60506754
# 41                 VAZIO   03/08/2022                   12851    68834561
# 42                 VAZIO   05/08/2022                   12867    61838339
# 43                 VAZIO   08/08/2022                   12890  2SSZ053348
#
#     Armador Tipo de Operação  \
# 0    MAERSK       Exportação
# 1    MAERSK       Exportação
# 2    MAERSK       Exportação
# 3    MAERSK       Exportação
# 4    MAERSK       Exportação
# 5    MAERSK       Exportação
# 6    MAERSK       Exportação
# 7    MAERSK       Exportação
# 8    MAERSK       Exportação
# 9    MAERSK       Exportação
# 10   MAERSK       Exportação
# 11    HAPAG       Exportação
# 12    HAPAG       Exportação
# 13    HAPAG       Exportação
# 14   MAERSK       Exportação
# 15   MAERSK       Exportação
# 16    HAPAG       Exportação
# 17    HAPAG       Exportação
# 18    HAPAG       Exportação
# 19    HAPAG       Exportação
# 20    HAPAG       Exportação
# 21    HAPAG       Exportação
# 22    HAPAG       Exportação
# 23    HAPAG       Exportação
# 24    HAPAG       Exportação
# 25    HAPAG       Exportação
# 26    HAPAG       Exportação
# 27    HAPAG       Exportação
# 28    HAPAG       Exportação
# 29    HAPAG       Exportação
# 30    HAPAG       Exportação
# 31    HAPAG       Exportação
# 32    HAPAG       Exportação
# 33    HAPAG       Exportação
# 34    HAPAG       Exportação
# 35    HAPAG       Exportação
# 36    HAPAG       Exportação
# 37    HAPAG       Exportação
# 38    HAPAG       Exportação
# 39    HAPAG       Exportação
# 40    HAPAG       Exportação
# 41    HAPAG       Exportação
# 42    HAPAG       Exportação
# 43  ALIANÇA       Exportação
#
#                                               Cliente  Seq. Item  \
# 0      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 1      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 2      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 3      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 4      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 5      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 6      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 7      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 8      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 9      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 10     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 11  29.667.227/0012-20 - Arlanxeo Brasil S.A. - 75...          1
# 12  29.667.227/0012-20 - Arlanxeo Brasil S.A. - 75...          1
# 13          88.037.668/0001-54 - TRAMONTINA MULTI S/A          1
# 14     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 15     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 16     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 17     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 18     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 19     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 20     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 21     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 22     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 23     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 24     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 25     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 26     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 27     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 28     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 29     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 30     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 31     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 32     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 33     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 34     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 35     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 36  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 37  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 38  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 39  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 40  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 41  29.667.227/0012-20 - Arlanxeo Brasil S.A. - 75...          2
# 42                        04.229.761/0011-42 - INNOVA          1
# 43     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          1
#
#                      Produto                   Nota Fiscal  \
# 0                 CNTR 40 HC                      793486-1
# 1                 CNTR 40 HC                      793537-1
# 2                 CNTR 40 HC                      793546-1
# 3                 CNTR 40 HC                      793554-1
# 4                 CNTR 40 HC                      793549-1
# 5                 CNTR 40 HC                      793548-1
# 6                 CNTR 40 HC                      793545-1
# 7                 CNTR 40 HC                      793571-1
# 8                 CNTR 40 HC                      793567-1
# 9                 CNTR 40 HC                      793570-1
# 10                CNTR 40 HC                      793559-1
# 11                CNTR 40 HC                       30155-1
# 12                CNTR 40 HC                       30158-1
# 13                CNTR 40 HC                      874961-1
# 14                CNTR 40 HC                      793476-1
# 15                CNTR 40 HC                      793475-1
# 16                CNTR 40 DC                      793517-1
# 17                CNTR 40 DC                     1334467-1
# 18                CNTR 40 DC                     1334502-1
# 19                CNTR 40 DC                     1334534-1
# 20                CNTR 40 DC                     1334599-1
# 21                CNTR 40 DC                     1334622-1
# 22                CNTR 40 DC                     1334648-1
# 23                CNTR 40 DC                     1334752-1
# 24                CNTR 40 DC                     1334796-1
# 25                CNTR 40 DC                     1334862-1
# 26                CNTR 40 DC                     1334889-1
# 27                CNTR 40 DC                     1334921-1
# 28                CNTR 40 DC                     1334985-1
# 29                CNTR 40 DC                     1334955-1
# 30                CNTR 40 DC                     1334970-1
# 31                CNTR 40 DC                      793430-1
# 32                CNTR 40 DC                      793447-1
# 33                CNTR 40 DC                      793466-1
# 34                CNTR 40 DC                      793477-1
# 35                CNTR 40 HC                      793595-1
# 36  CNTR 40 HC SUPER TESTADO                       86520-1
# 37  CNTR 40 HC SUPER TESTADO                       86525-1
# 38  CNTR 40 HC SUPER TESTADO                       86532-1
# 39  CNTR 40 HC SUPER TESTADO                       86530-1
# 40  CNTR 40 HC SUPER TESTADO                       86523-1
# 41                CNTR 40 HC                       30161-1
# 42  CNTR 40 HC SUPER TESTADO                     115839-20
# 43                CNTR 40 HC  793221-1/793220-1 /1334399-1
#
#                                     NCM          Peso Bruto              CT-e
# 0                              39011030               25500           18450-2
# 1                              39011030               25500           18456-2
# 2                              39011030               25500           18457-2
# 3                              39011030               25500           18458-2
# 4                              39011030               25500           18459-2
# 5                              39011030               25500           18460-2
# 6                              39011030               25500           18461-2
# 7                              39011030               25500           18462-2
# 8                              39011030               25500           18463-2
# 9                              39011030               25500           18464-2
# 10                             39011030               25500           18465-2
# 11                             39023000               21274           18435-2
# 12                             40027000               21274           18438-2
# 13  44170090,82011000,82014000,82019000               13171           18432-2
# 14                             39011030             25591.5           18441-2
# 15                             39011030             25591.5           18442-2
# 16                             39011030            25616.25           18451-2
# 17                             39023000               25500           18419-2
# 18                             39023000               25500           18420-2
# 19                             39023000               25500           18426-2
# 20                             39023000               25500           18429-2
# 21                             39023000               25500           18431-2
# 22                             39023000               25500           18430-2
# 23                             39023000               25500           18440-2
# 24                             39023000               25500           18454-2
# 25                             39023000               25500           18453-2
# 26                             39023000               25500           18455-2
# 27                             39023000               25500           18466-2
# 28                             39023000               25500           18467-2
# 29                             39023000               25500           18468-2
# 30                             39023000               25500           18469-2
# 31                             39011030            25616.25           18436-2
# 32                             39011030            25616.25           18437-2
# 33                             39011030            25616.25           18444-2
# 34                             39011030            25616.25           18445-2
# 35                             39011030            25616.25           18470-2
# 36                    40021919,73090090               25020           18446-2
# 37                    40021919,73090090               25020           18471-2
# 38                    40021919,73090090               25020           18474-2
# 39                    40021919,73090090               25020           18472-2
# 40                    40021919,73090090               25020           18473-2
# 41                             40027000               22059           18443-2
# 42                             39031900               27930           18439-2
# 43                    39011030/39011030  1421.750/22440.000  18433-2 /18434-2

# %%
df.columns
# Out:
# Index(['Código da Viagem', 'Container', 'Tara', 'ISO', 'Lacre',
#        'Situação do Container', 'Data Vínculo', 'Solicitação Transporte',
#        'Booking/DI', 'Armador', 'Tipo de Operação', 'Cliente', 'Seq. Item',
#        'Produto', 'Nota Fiscal', 'NCM', 'Peso Bruto', 'CT-e'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Código da Viagem          object
# Container                 object
# Tara                      object
# ISO                       object
# Lacre                     object
# Situação do Container     object
# Data Vínculo              object
# Solicitação Transporte     int64
# Booking/DI                object
# Armador                   object
# Tipo de Operação          object
# Cliente                   object
# Seq. Item                  int64
# Produto                   object
# Nota Fiscal               object
# NCM                       object
# Peso Bruto                object
# CT-e                      object
# dtype: object

# %%
lst_ISO = df['ISO'].to_list()
lst_cubagem = []
i = 0
for item in lst_ISO:
    print(str(item) + " " + str(i))
    if item[:2] == '45' or item[:2] == '42':
        lst_cubagem.append('60000')
    elif item[:2] == '22':
        lst_cubagem.append('30000')
    i = i +1
    
print(len(lst_cubagem))
df['Cubagem'] = lst_cubagem
df
# Out:
# 45G1 0
# 45G1 1
# 45G1 2
# 45G1 3
# 45G1 4
# 45G1 5
# 45G1 6
# 45G1 7
# 45G1 8
# 45G1 9
# 45G1 10
# 45G1 11
# 45G1 12
# 45G1 13
# 45G1 14
# 45G1 15
# 45G1 16
# 45G1 17
# 45G1 18
# 45G1 19
# 45G1 20
# 45G1 21
# 45G1 22
# 45G1 23
# 45G1 24
# 45G1 25
# 45G1 26
# 45G1 27
# 45G1 28
# 45G1 29
# 45G1 30
# 45G1 31
# 45G1 32
# 45G1 33
# 45G1 34
# 45G1 35
# 45G1 36
# 45G1 37
# 45G1 38
# 45G1 39
# 45G1 40
# 45G1 41
# 45G1 42
# 45G1 43
# 44
#    Código da Viagem    Container      Tara   ISO        Lacre  \
# 0     GUARITA 0597S  CAAU6627492  3.700,00  45G1  MLBR2540106
# 1     GUARITA 0597S  GESU6076986  3.870,00  45G1  MLBR2540108
# 2     GUARITA 0597S  MRKU3535226  3.880,00  45G1  MLBR2540112
# 3     GUARITA 0597S  MRKU4708028  3.880,00  45G1  MLBR2540113
# 4     GUARITA 0597S  MRKU5427806  3.810,00  45G1  MLBR2540114
# 5     GUARITA 0597S  MSKU1383240  3.880,00  45G1  MLBR2540115
# 6     GUARITA 0597S  MSKU1840520  3.880,00  45G1  MLBR2540116
# 7     GUARITA 0597S  MSKU1993725  3.880,00  45G1  MLBR2540117
# 8     GUARITA 0597S  MSKU9617025  3.910,00  45G1  MLBR2540118
# 9     GUARITA 0597S  TCLU8382865  4.000,00  45G1  MLBR2540119
# 10    GUARITA 0597S  TRHU8485843  3.700,00  45G1  MLBR2540120
# 11    GUARITA 0597S  HLXU6500920  4.090,00  45G1  HLD11880126
# 12    GUARITA 0597S  FANU1469555  3.680,00  45G1  HLD11880127
# 13    GUARITA 0597S  TCNU1800831  3.700,00  45G1  HLD11880125
# 14    GUARITA 0597S  MAGU5493650  4.000,00  45G1  MLBR2540162
# 15    GUARITA 0597S  TCNU8123440  3.700,00  45G1  MLBR2540163
# 16    GUARITA 0597S  UACU5892099  3.900,00  45G1  HLD11858371
# 17    GUARITA 0597S  UACU5642377  3.800,00  45G1  HLD11858323
# 18    GUARITA 0597S  HLBU1078179  3.900,00  45G1  HLD11858328
# 19    GUARITA 0597S  HLBU2176945  3.900,00  45G1  HLD11858382
# 20    GUARITA 0597S  FFAU1336836  3.700,00  45G1  HLD11858326
# 21    GUARITA 0597S  TGHU9453073  3.890,00  45G1  HLD11858353
# 22    GUARITA 0597S  HLBU3234692  3.900,00  45G1  HLD11858388
# 23    GUARITA 0597S  HLXU8349161  3.900,00  45G1  HLD11858345
# 24    GUARITA 0597S  HLBU2813513  3.910,00  45G1  HLD11858268
# 25    GUARITA 0597S  FANU1401730  3.900,00  45G1  HLD11858288
# 26    GUARITA 0597S  HLBU2116695  3.900,00  45G1  HLD11858278
# 27    GUARITA 0597S  UETU5734117  3.700,00  45G1  HLD11858372
# 28    GUARITA 0597S  TCLU8365868  3.840,00  45G1  HLD11858346
# 29    GUARITA 0597S  HAMU1302150  3.900,00  45G1  HLD11858295
# 30    GUARITA 0597S  UACU5251454  3.970,00  45G1  HLD11858387
# 31    GUARITA 0597S  HLBU2458743  3.900,00  45G1  HLD11858304
# 32    GUARITA 0597S  HLBU2657405  3.900,00  45G1  HLD11858383
# 33    GUARITA 0597S  CAIU4259809  3.750,00  45G1  HLD11858385
# 34    GUARITA 0597S  HLXU8527160  3.900,00  45G1  HLD11858322
# 35    GUARITA 0597S  UACU5878336  3.800,00  45G1   HLG3885740
# 36    GUARITA 0597S  HLBU1855670  3.900,00  45G1  HLD11858270
# 37    GUARITA 0597S  SEGU5679830  3.830,00  45G1  HLD11858330
# 38    GUARITA 0597S  CAIU8521922  3.820,00  45G1  HLD11861261
# 39    GUARITA 0597S  HAMU1306411  3.900,00  45G1  HLD11858350
# 40    GUARITA 0597S  HLXU8415448  3.900,00  45G1  HLD11861248
# 41    GUARITA 0597S  UACU5304699  3.970,00  45G1  HLD11861250
# 42    GUARITA 0597S  TCLU8643336  3.840,00  45G1  HLD11880128
# 43    GUARITA 0597S  CIPU5246519  3.700,00  45G1    BR1585138
#
#    Situação do Container Data Vínculo  Solicitação Transporte  Booking/DI  \
# 0                  VAZIO   26/07/2022                   12737   219016888
# 1                  VAZIO   26/07/2022                   12737   219016888
# 2                  VAZIO   26/07/2022                   12737   219016888
# 3                  VAZIO   26/07/2022                   12737   219016888
# 4                  VAZIO   26/07/2022                   12737   219016888
# 5                  VAZIO   26/07/2022                   12737   219016888
# 6                  VAZIO   26/07/2022                   12737   219016888
# 7                  VAZIO   26/07/2022                   12737   219016888
# 8                  VAZIO   26/07/2022                   12737   219016888
# 9                  VAZIO   26/07/2022                   12737   219016888
# 10                 VAZIO   26/07/2022                   12737   219016888
# 11                 VAZIO   01/08/2022                   12775    64167899
# 12                 VAZIO   01/08/2022                   12776    65167898
# 13                 VAZIO   01/08/2022                   12777    61502559
# 14                 VAZIO   01/08/2022                   12790   219763096
# 15                 VAZIO   01/08/2022                   12790   219763096
# 16                 VAZIO   02/08/2022                   12809    67168141
# 17                 VAZIO   02/08/2022                   12818    68167618
# 18                 VAZIO   02/08/2022                   12818    68167618
# 19                 VAZIO   02/08/2022                   12818    68167618
# 20                 VAZIO   02/08/2022                   12818    68167618
# 21                 VAZIO   02/08/2022                   12818    68167618
# 22                 VAZIO   02/08/2022                   12818    68167618
# 23                 VAZIO   02/08/2022                   12818    68167618
# 24                 VAZIO   02/08/2022                   12818    68167618
# 25                 VAZIO   02/08/2022                   12818    68167618
# 26                 VAZIO   02/08/2022                   12818    68167618
# 27                 VAZIO   02/08/2022                   12818    68167618
# 28                 VAZIO   02/08/2022                   12818    68167618
# 29                 VAZIO   02/08/2022                   12818    68167618
# 30                 VAZIO   02/08/2022                   12818    68167618
# 31                 VAZIO   02/08/2022                   12823    63835235
# 32                 VAZIO   02/08/2022                   12823    63835235
# 33                 VAZIO   02/08/2022                   12823    63835235
# 34                 VAZIO   02/08/2022                   12823    63835235
# 35                 VAZIO   03/08/2022                   12841    65167970
# 36                 VAZIO   03/08/2022                   12850    60506754
# 37                 VAZIO   03/08/2022                   12850    60506754
# 38                 VAZIO   03/08/2022                   12850    60506754
# 39                 VAZIO   03/08/2022                   12850    60506754
# 40                 VAZIO   03/08/2022                   12850    60506754
# 41                 VAZIO   03/08/2022                   12851    68834561
# 42                 VAZIO   05/08/2022                   12867    61838339
# 43                 VAZIO   08/08/2022                   12890  2SSZ053348
#
#     Armador Tipo de Operação  \
# 0    MAERSK       Exportação
# 1    MAERSK       Exportação
# 2    MAERSK       Exportação
# 3    MAERSK       Exportação
# 4    MAERSK       Exportação
# 5    MAERSK       Exportação
# 6    MAERSK       Exportação
# 7    MAERSK       Exportação
# 8    MAERSK       Exportação
# 9    MAERSK       Exportação
# 10   MAERSK       Exportação
# 11    HAPAG       Exportação
# 12    HAPAG       Exportação
# 13    HAPAG       Exportação
# 14   MAERSK       Exportação
# 15   MAERSK       Exportação
# 16    HAPAG       Exportação
# 17    HAPAG       Exportação
# 18    HAPAG       Exportação
# 19    HAPAG       Exportação
# 20    HAPAG       Exportação
# 21    HAPAG       Exportação
# 22    HAPAG       Exportação
# 23    HAPAG       Exportação
# 24    HAPAG       Exportação
# 25    HAPAG       Exportação
# 26    HAPAG       Exportação
# 27    HAPAG       Exportação
# 28    HAPAG       Exportação
# 29    HAPAG       Exportação
# 30    HAPAG       Exportação
# 31    HAPAG       Exportação
# 32    HAPAG       Exportação
# 33    HAPAG       Exportação
# 34    HAPAG       Exportação
# 35    HAPAG       Exportação
# 36    HAPAG       Exportação
# 37    HAPAG       Exportação
# 38    HAPAG       Exportação
# 39    HAPAG       Exportação
# 40    HAPAG       Exportação
# 41    HAPAG       Exportação
# 42    HAPAG       Exportação
# 43  ALIANÇA       Exportação
#
#                                               Cliente  Seq. Item  \
# 0      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 1      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 2      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 3      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 4      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 5      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 6      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 7      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 8      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 9      42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 10     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 11  29.667.227/0012-20 - Arlanxeo Brasil S.A. - 75...          1
# 12  29.667.227/0012-20 - Arlanxeo Brasil S.A. - 75...          1
# 13          88.037.668/0001-54 - TRAMONTINA MULTI S/A          1
# 14     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 15     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 16     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 17     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 18     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 19     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 20     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 21     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 22     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 23     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 24     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 25     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 26     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 27     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 28     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 29     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 30     42.150.391/0037-81 - Braskem S.A - RSA2 / RS07          2
# 31     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 32     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 33     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 34     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 35     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          2
# 36  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 37  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 38  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 39  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 40  29.667.227/0006-81 - Arlanxeo Brasil S.A. - 15...          2
# 41  29.667.227/0012-20 - Arlanxeo Brasil S.A. - 75...          2
# 42                        04.229.761/0011-42 - INNOVA          1
# 43     42.150.391/0010-61 - Braskem S.A - RSA1 / RS01          1
#
#                      Produto                   Nota Fiscal  \
# 0                 CNTR 40 HC                      793486-1
# 1                 CNTR 40 HC                      793537-1
# 2                 CNTR 40 HC                      793546-1
# 3                 CNTR 40 HC                      793554-1
# 4                 CNTR 40 HC                      793549-1
# 5                 CNTR 40 HC                      793548-1
# 6                 CNTR 40 HC                      793545-1
# 7                 CNTR 40 HC                      793571-1
# 8                 CNTR 40 HC                      793567-1
# 9                 CNTR 40 HC                      793570-1
# 10                CNTR 40 HC                      793559-1
# 11                CNTR 40 HC                       30155-1
# 12                CNTR 40 HC                       30158-1
# 13                CNTR 40 HC                      874961-1
# 14                CNTR 40 HC                      793476-1
# 15                CNTR 40 HC                      793475-1
# 16                CNTR 40 DC                      793517-1
# 17                CNTR 40 DC                     1334467-1
# 18                CNTR 40 DC                     1334502-1
# 19                CNTR 40 DC                     1334534-1
# 20                CNTR 40 DC                     1334599-1
# 21                CNTR 40 DC                     1334622-1
# 22                CNTR 40 DC                     1334648-1
# 23                CNTR 40 DC                     1334752-1
# 24                CNTR 40 DC                     1334796-1
# 25                CNTR 40 DC                     1334862-1
# 26                CNTR 40 DC                     1334889-1
# 27                CNTR 40 DC                     1334921-1
# 28                CNTR 40 DC                     1334985-1
# 29                CNTR 40 DC                     1334955-1
# 30                CNTR 40 DC                     1334970-1
# 31                CNTR 40 DC                      793430-1
# 32                CNTR 40 DC                      793447-1
# 33                CNTR 40 DC                      793466-1
# 34                CNTR 40 DC                      793477-1
# 35                CNTR 40 HC                      793595-1
# 36  CNTR 40 HC SUPER TESTADO                       86520-1
# 37  CNTR 40 HC SUPER TESTADO                       86525-1
# 38  CNTR 40 HC SUPER TESTADO                       86532-1
# 39  CNTR 40 HC SUPER TESTADO                       86530-1
# 40  CNTR 40 HC SUPER TESTADO                       86523-1
# 41                CNTR 40 HC                       30161-1
# 42  CNTR 40 HC SUPER TESTADO                     115839-20
# 43                CNTR 40 HC  793221-1/793220-1 /1334399-1
#
#                                     NCM          Peso Bruto              CT-e  \
# 0                              39011030               25500           18450-2
# 1                              39011030               25500           18456-2
# 2                              39011030               25500           18457-2
# 3                              39011030               25500           18458-2
# 4                              39011030               25500           18459-2
# 5                              39011030               25500           18460-2
# 6                              39011030               25500           18461-2
# 7                              39011030               25500           18462-2
# 8                              39011030               25500           18463-2
# 9                              39011030               25500           18464-2
# 10                             39011030               25500           18465-2
# 11                             39023000               21274           18435-2
# 12                             40027000               21274           18438-2
# 13  44170090,82011000,82014000,82019000               13171           18432-2
# 14                             39011030             25591.5           18441-2
# 15                             39011030             25591.5           18442-2
# 16                             39011030            25616.25           18451-2
# 17                             39023000               25500           18419-2
# 18                             39023000               25500           18420-2
# 19                             39023000               25500           18426-2
# 20                             39023000               25500           18429-2
# 21                             39023000               25500           18431-2
# 22                             39023000               25500           18430-2
# 23                             39023000               25500           18440-2
# 24                             39023000               25500           18454-2
# 25                             39023000               25500           18453-2
# 26                             39023000               25500           18455-2
# 27                             39023000               25500           18466-2
# 28                             39023000               25500           18467-2
# 29                             39023000               25500           18468-2
# 30                             39023000               25500           18469-2
# 31                             39011030            25616.25           18436-2
# 32                             39011030            25616.25           18437-2
# 33                             39011030            25616.25           18444-2
# 34                             39011030            25616.25           18445-2
# 35                             39011030            25616.25           18470-2
# 36                    40021919,73090090               25020           18446-2
# 37                    40021919,73090090               25020           18471-2
# 38                    40021919,73090090               25020           18474-2
# 39                    40021919,73090090               25020           18472-2
# 40                    40021919,73090090               25020           18473-2
# 41                             40027000               22059           18443-2
# 42                             39031900               27930           18439-2
# 43                    39011030/39011030  1421.750/22440.000  18433-2 /18434-2
#
#    Cubagem
# 0    60000
# 1    60000
# 2    60000
# 3    60000
# 4    60000
# 5    60000
# 6    60000
# 7    60000
# 8    60000
# 9    60000
# 10   60000
# 11   60000
# 12   60000
# 13   60000
# 14   60000
# 15   60000
# 16   60000
# 17   60000
# 18   60000
# 19   60000
# 20   60000
# 21   60000
# 22   60000
# 23   60000
# 24   60000
# 25   60000
# 26   60000
# 27   60000
# 28   60000
# 29   60000
# 30   60000
# 31   60000
# 32   60000
# 33   60000
# 34   60000
# 35   60000
# 36   60000
# 37   60000
# 38   60000
# 39   60000
# 40   60000
# 41   60000
# 42   60000
# 43   60000

# %%
df_guarita = df[['ISO', 'Container', 'Tara', 'Peso Bruto', 'NCM', 'Lacre', 'Cubagem' ]]

# %%
df_guarita.head()
# Out:
#     ISO    Container      Tara Peso Bruto       NCM        Lacre Cubagem
# 0  45G1  CAAU6627492  3.700,00      25500  39011030  MLBR2540106   60000
# 1  45G1  GESU6076986  3.870,00      25500  39011030  MLBR2540108   60000
# 2  45G1  MRKU3535226  3.880,00      25500  39011030  MLBR2540112   60000
# 3  45G1  MRKU4708028  3.880,00      25500  39011030  MLBR2540113   60000
# 4  45G1  MRKU5427806  3.810,00      25500  39011030  MLBR2540114   60000

# %%
df_guarita.dtypes
# Out:
# ISO           object
# Container     object
# Tara          object
# Peso Bruto    object
# NCM           object
# Lacre         object
# Cubagem       object
# dtype: object

# %%
guarita_dict = df_guarita.to_dict(orient = 'index')
guarita_dict
# Out:
# {0: {'ISO': '45G1',
#   'Container': 'CAAU6627492',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540106',
#   'Cubagem': '60000'},
#  1: {'ISO': '45G1',
#   'Container': 'GESU6076986',
#   'Tara': '3.870,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540108',
#   'Cubagem': '60000'},
#  2: {'ISO': '45G1',
#   'Container': 'MRKU3535226',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540112',
#   'Cubagem': '60000'},
#  3: {'ISO': '45G1',
#   'Container': 'MRKU4708028',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540113',
#   'Cubagem': '60000'},
#  4: {'ISO': '45G1',
#   'Container': 'MRKU5427806',
#   'Tara': '3.810,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540114',
#   'Cubagem': '60000'},
#  5: {'ISO': '45G1',
#   'Container': 'MSKU1383240',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540115',
#   'Cubagem': '60000'},
#  6: {'ISO': '45G1',
#   'Container': 'MSKU1840520',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540116',
#   'Cubagem': '60000'},
#  7: {'ISO': '45G1',
#   'Container': 'MSKU1993725',
#   'Tara': '3.880,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540117',
#   'Cubagem': '60000'},
#  8: {'ISO': '45G1',
#   'Container': 'MSKU9617025',
#   'Tara': '3.910,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540118',
#   'Cubagem': '60000'},
#  9: {'ISO': '45G1',
#   'Container': 'TCLU8382865',
#   'Tara': '4.000,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540119',
#   'Cubagem': '60000'},
#  10: {'ISO': '45G1',
#   'Container': 'TRHU8485843',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540120',
#   'Cubagem': '60000'},
#  11: {'ISO': '45G1',
#   'Container': 'HLXU6500920',
#   'Tara': '4.090,00',
#   'Peso Bruto': 21274,
#   'NCM': 39023000,
#   'Lacre': 'HLD11880126',
#   'Cubagem': '60000'},
#  12: {'ISO': '45G1',
#   'Container': 'FANU1469555',
#   'Tara': '3.680,00',
#   'Peso Bruto': 21274,
#   'NCM': 40027000,
#   'Lacre': 'HLD11880127',
#   'Cubagem': '60000'},
#  13: {'ISO': '45G1',
#   'Container': 'TCNU1800831',
#   'Tara': '3.700,00',
#   'Peso Bruto': 13171,
#   'NCM': '44170090,82011000,82014000,82019000',
#   'Lacre': 'HLD11880125',
#   'Cubagem': '60000'},
#  14: {'ISO': '45G1',
#   'Container': 'MAGU5493650',
#   'Tara': '4.000,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540162',
#   'Cubagem': '60000'},
#  15: {'ISO': '45G1',
#   'Container': 'TCNU8123440',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25591.5,
#   'NCM': 39011030,
#   'Lacre': 'MLBR2540163',
#   'Cubagem': '60000'},
#  16: {'ISO': '45G1',
#   'Container': 'UACU5892099',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25616.25,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858371',
#   'Cubagem': '60000'},
#  17: {'ISO': '45G1',
#   'Container': 'UACU5642377',
#   'Tara': '3.800,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858323',
#   'Cubagem': '60000'},
#  18: {'ISO': '45G1',
#   'Container': 'HLBU1078179',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858328',
#   'Cubagem': '60000'},
#  19: {'ISO': '45G1',
#   'Container': 'HLBU2176945',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858382',
#   'Cubagem': '60000'},
#  20: {'ISO': '45G1',
#   'Container': 'FFAU1336836',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858326',
#   'Cubagem': '60000'},
#  21: {'ISO': '45G1',
#   'Container': 'TGHU9453073',
#   'Tara': '3.890,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858353',
#   'Cubagem': '60000'},
#  22: {'ISO': '45G1',
#   'Container': 'HLBU3234692',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858388',
#   'Cubagem': '60000'},
#  23: {'ISO': '45G1',
#   'Container': 'HLXU8349161',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858345',
#   'Cubagem': '60000'},
#  24: {'ISO': '45G1',
#   'Container': 'HLBU2813513',
#   'Tara': '3.910,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858268',
#   'Cubagem': '60000'},
#  25: {'ISO': '45G1',
#   'Container': 'FANU1401730',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858288',
#   'Cubagem': '60000'},
#  26: {'ISO': '45G1',
#   'Container': 'HLBU2116695',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858278',
#   'Cubagem': '60000'},
#  27: {'ISO': '45G1',
#   'Container': 'UETU5734117',
#   'Tara': '3.700,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858372',
#   'Cubagem': '60000'},
#  28: {'ISO': '45G1',
#   'Container': 'TCLU8365868',
#   'Tara': '3.840,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858346',
#   'Cubagem': '60000'},
#  29: {'ISO': '45G1',
#   'Container': 'HAMU1302150',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858295',
#   'Cubagem': '60000'},
#  30: {'ISO': '45G1',
#   'Container': 'UACU5251454',
#   'Tara': '3.970,00',
#   'Peso Bruto': 25500,
#   'NCM': 39023000,
#   'Lacre': 'HLD11858387',
#   'Cubagem': '60000'},
#  31: {'ISO': '45G1',
#   'Container': 'HLBU2458743',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25616.25,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858304',
#   'Cubagem': '60000'},
#  32: {'ISO': '45G1',
#   'Container': 'HLBU2657405',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25616.25,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858383',
#   'Cubagem': '60000'},
#  33: {'ISO': '45G1',
#   'Container': 'CAIU4259809',
#   'Tara': '3.750,00',
#   'Peso Bruto': 25616.25,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858385',
#   'Cubagem': '60000'},
#  34: {'ISO': '45G1',
#   'Container': 'HLXU8527160',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25616.25,
#   'NCM': 39011030,
#   'Lacre': 'HLD11858322',
#   'Cubagem': '60000'},
#  35: {'ISO': '45G1',
#   'Container': 'UACU5878336',
#   'Tara': '3.800,00',
#   'Peso Bruto': 25616.25,
#   'NCM': 39011030,
#   'Lacre': 'HLG3885740',
#   'Cubagem': '60000'},
#  36: {'ISO': '45G1',
#   'Container': 'HLBU1855670',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'HLD11858270',
#   'Cubagem': '60000'},
#  37: {'ISO': '45G1',
#   'Container': 'SEGU5679830',
#   'Tara': '3.830,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'HLD11858330',
#   'Cubagem': '60000'},
#  38: {'ISO': '45G1',
#   'Container': 'CAIU8521922',
#   'Tara': '3.820,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'HLD11861261',
#   'Cubagem': '60000'},
#  39: {'ISO': '45G1',
#   'Container': 'HAMU1306411',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'HLD11858350',
#   'Cubagem': '60000'},
#  40: {'ISO': '45G1',
#   'Container': 'HLXU8415448',
#   'Tara': '3.900,00',
#   'Peso Bruto': 25020,
#   'NCM': '40021919,73090090',
#   'Lacre': 'HLD11861248',
#   'Cubagem': '60000'},
#  41: {'ISO': '45G1',
#   'Container': 'UACU5304699',
#   'Tara': '3.970,00',
#   'Peso Bruto': 22059,
#   'NCM': 40027000,
#   'Lacre': 'HLD11861250',
#   'Cubagem': '60000'},
#  42: {'ISO': '45G1',
#   'Container': 'TCLU8643336',
#   'Tara': '3.840,00',
#   'Peso Bruto': 27930,
#   'NCM': 39031900,
#   'Lacre': 'HLD11880128',
#   'Cubagem': '60000'},
#  43: {'ISO': '45G1',
#   'Container': 'CIPU5246519',
#   'Tara': '3.700,00',
#   'Peso Bruto': '1421.750/22440.000',
#   'NCM': '39011030/39011030',
#   'Lacre': 'BR1585138',
#   'Cubagem': '60000'}}

# %%
len(guarita_dict)
# Out:
# 44

# %%
# Teste
#driver.switch_to.default_content()


'''driver.switch_to.frame('Principal')
e = driver.find_element(By.XPATH, '/html/body/form/div/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[2]/input[1]').send_keys('teste')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[4]/input').send_keys('test')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[2]/input').send_keys('test')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[4]/input').send_keys('test')
e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[3]/td[2]/input').send_keys('test')
e = driver.find_element(By.XPATH, '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[1]/fieldset/table/tbody/tr[1]/td[2]/input[1]').send_keys('test')''''''
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# Input In [45], in <cell line: 2>()
#       1 # Teste
# ----> 2 driver.switch_to.default_content()
#       5 driver.switch_to.frame('Principal')
#       6 e = driver.find_element(By.XPATH, '/html/body/form/div/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[2]/input[1]').send_keys('teste')
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\switch_to.py:68, in SwitchTo.default_content(self)
#      59 def default_content(self) -> None:
#      60     """
#      61     Switch focus to the default frame.
#      62
#    (...)
#      66             driver.switch_to.default_content()
#      67     """
# ---> 68     self._driver.execute(Command.SWITCH_TO_FRAME, {'id': None})
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:246, in ErrorHandler.check_response(self, response)
#     244     elif 'alert' in value:
#     245         alert_text = value['alert'].get('text')
# --> 246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
#     247 raise exception_class(message, screen, stacktrace)
#
# UnexpectedAlertPresentException: Alert Text: Esta sessÃ£o foi encerrada!!! FaÃ§aa o login novamente.
# Message: unexpected alert open: {Alert text : Esta sessÃ£o foi encerrada!!! FaÃ§aa o login novamente.}
#   (Session info: chrome=104.0.5112.81)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x007B78B3+2193587]
# 	Ordinal0 [0x00750681+1771137]
# 	Ordinal0 [0x006641A8+803240]
# 	Ordinal0 [0x006BD952+1169746]
# 	Ordinal0 [0x006AD5C6+1103302]
# 	Ordinal0 [0x006877E0+948192]
# 	Ordinal0 [0x006886E6+952038]
# 	GetHandleVerifier [0x00A60CB2+2738370]
# 	GetHandleVerifier [0x00A521B8+2678216]
# 	GetHandleVerifier [0x008417AA+512954]
# 	GetHandleVerifier [0x00840856+509030]
# 	Ordinal0 [0x0075743B+1799227]
# 	Ordinal0 [0x0075BB68+1817448]
# 	Ordinal0 [0x0075BC55+1817685]
# 	Ordinal0 [0x00765230+1856048]
# 	BaseThreadInitThunk [0x7704FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77887A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77887A6E+238]

# %%
#sleep(3)
count = 0
driver.maximize_window
frames = driver.find_elements()

while count <= len(guarita_dict):


    for item in guarita_dict[count]:
        
        driver.switch_to.default_content()
        driver.switch_to.frame('Principal')
#ISO     
    
        # get xpath for ISO
        #print(driver.name)
        #print(driver.current_url)
        e = driver.find_element('name',"ItemCarga_tipoContainer")
        e = driver.find_element(By.XPATH, '/html/body/form/div/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[2]/input[1]')
        e.send_keys(guarita_dict[count]['ISO'])
        
        # print confirmação
        print(guarita_dict[count]['ISO'])
        sleep(0.5)

#CONTAINER
        # get xpath for Container 
        
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[1]/td[4]/input')
        e.send_keys(guarita_dict[count]['Container'])

        # print confirmação
        print(guarita_dict[count]['Container'])
        sleep(0.5)

#TARA
        # get xpath for Tara
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[2]/input')
        e.send_keys(guarita_dict[count]['Tara'])
        
        # print confirmação
        print(guarita_dict[count]['Tara'])
        sleep(0.5)

#PESO_BRUTO
        # get xpath for Peso Bruto
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[2]/td[4]/input')
        e.send_keys(guarita_dict[count]['Peso Bruto'])
        
        # print confirmação
        print(guarita_dict[count]['Peso Bruto'])
        sleep(0.5)
        
        
#CUBAGEM
        # startswith
       
        # get xpath for CUBAGEM
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/fieldset[1]/table/tbody/tr[3]/td[2]/input')
        e.send_keys(guarita_dict[count]['Cubagem'])
        
        # print confirmação
        print(guarita_dict[count]['Cubagem'])
        sleep(0.5)
        
# NCM
        ncms = str(guarita_dict[count]['NCM']).split('/')            
        
        # split "/" e loop for para múltiplas inserções
        for item in ncms:
            # get xpath for NCM
            e = driver.find_element(By.XPATH, '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[1]/fieldset/table/tbody/tr[1]/td[2]/input[1]')
            e.send_keys(item)
            # get xpath for "incluir"
            e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[1]/fieldset/table/tbody/tr[2]/td/input')
            e.click()
            print(item)
            sleep(0.5)
        
        
        ##### SE TIVER / INSERIR VÁRIAS VEZES. EX: PRIMEIRA VEZ, ATÉ A BARRA; SEGUNDA VEZ, ATÉ A PRÓXIMA BARRA;
        ### TERCEIRA VEZ, ATÉ A PRÓXIMA BARRA
        
        

        #get xpath for Lacre
        e = driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td[2]/input')
        e.send_keys(guarita_dict[count]['Lacre'])
        
        print(guarita_dict[count]['Lacre'])
        sleep(0.5)
        
        # get xpath for "incluir"
        driver.find_element('xpath', '//*[@id="divCampos"]/fieldset[3]/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/input').click()
        
        print('Click - Clicar em inserir Item.')
        sleep(0.5)
        
        #input('press enter to continue')
        
        
# INCLUIR ITEM        
        #driver.find_element('xpath', '//*[@id="divCampos"]/p[2]/input[1]').click()
        input('press enter to continue')
    
# INCLUIR NOVO ITEM - radio button

        #driver.find_element('xpath', '/html/body/form[1]/fieldset[5]/table/tbody/tr/td[1]/input[1]').click()
        input('press enter to continue')

        print('marcar inserir novo item')
        sleep(3)
        
# ENVIAR
        # driver.find_element('xpath', '/html/body/form[1]/p[2]/input')
        #print('clicar em enviar')
        input('press enter to continue')
        sleep(3)

        count += 1
        input('Aperte enter para prosseguir')

        print('----- next one-----')
# Out:
# 45G1
# CAAU6627492
# 3.700,00
# 25500
# 60000
# 39011030
# MLBR2540106
# Click - Clicar em inserir Item.

# %%
nnn = "34933223/3243232/1231312"

# %%
nnn = nnn.split('/')

# %%
for item in nnn:
    print(item)
# Out:
# 34933223
# 3243232
# 1231312

# %%
dict_df = df.to_dict(orient = 'index')

# %%
dict_df
